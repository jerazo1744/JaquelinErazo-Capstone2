# %%
import pandas as pd
import numpy as np
from datetime import datetime
import gzip

# %%
listings = pd.read_csv("~/Desktop/TTP_DATA/JaquelinErazo-Capstone2/DATA/listings.csv")

# %%
neighborhoods = pd.read_csv("~/Desktop/TTP_DATA/JaquelinErazo-Capstone2/DATA/neighbourhoods.csv")

# %%
reviews = pd.read_csv("~/Desktop/TTP_DATA/JaquelinErazo-Capstone2/DATA/reviews.csv")

# %%
listings.head()
# Out:
#      id                               name  host_id host_name  \
# 0  2577   Loft for 4 by Canal Saint Martin     2827    Karine
# 1  3109                       zen and calm     3631      Anne
# 2  5396     Explore the heart of old Paris     7903    Borzou
# 3  7397   MARAIS - 2ROOMS APT - 2/4 PEOPLE     2626    Franck
# 4  7964  Large & sunny flat with balcony !    22155     Anaïs
#
#    neighbourhood_group   neighbourhood  latitude  longitude        room_type  \
# 0                  NaN        Entrepôt  48.86993    2.36251  Entire home/apt
# 1                  NaN    Observatoire  48.83349    2.31852  Entire home/apt
# 2                  NaN  Hôtel-de-Ville  48.85100    2.35869  Entire home/apt
# 3                  NaN  Hôtel-de-Ville  48.85758    2.35275  Entire home/apt
# 4                  NaN           Opéra  48.87417    2.34245  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    125               3                  1  2019-01-02               0.06
# 1     60               2                  9  2019-10-24               0.22
# 2    115               1                220  2020-03-22               1.66
# 3    119              10                268  2020-02-26               2.42
# 4    130               6                  6  2015-09-14               0.05
#
#    calculated_host_listings_count  availability_365
# 0                               1               365
# 1                               1               365
# 2                               1                91
# 3                               5               264
# 4                               1               330

# %%
neighborhoods.head()
# Out:
#    neighbourhood_group        neighbourhood
# 0                  NaN  Batignolles-Monceau
# 1                  NaN               Bourse
# 2                  NaN      Buttes-Chaumont
# 3                  NaN    Buttes-Montmartre
# 4                  NaN               Élysée

# %%
reviews.head()
# Out:
#    listing_id        date
# 0        2577  2019-01-02
# 1        3109  2016-12-27
# 2        3109  2016-12-28
# 3        3109  2017-10-28
# 4        3109  2017-11-03

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66900 entries, 0 to 66899
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              66900 non-null  int64
#  1   name                            66834 non-null  object
#  2   host_id                         66900 non-null  int64
#  3   host_name                       66890 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   66900 non-null  object
#  6   latitude                        66900 non-null  float64
#  7   longitude                       66900 non-null  float64
#  8   room_type                       66900 non-null  object
#  9   price                           66900 non-null  int64
#  10  minimum_nights                  66900 non-null  int64
#  11  number_of_reviews               66900 non-null  int64
#  12  last_review                     52901 non-null  object
#  13  reviews_per_month               52901 non-null  float64
#  14  calculated_host_listings_count  66900 non-null  int64
#  15  availability_365                66900 non-null  int64
# dtypes: float64(4), int64(7), object(5)
# memory usage: 8.2+ MB

# %%
neighborhoods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   neighbourhood_group  0 non-null      float64
#  1   neighbourhood        20 non-null     object
# dtypes: float64(1), object(1)
# memory usage: 448.0+ bytes

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1363744 entries, 0 to 1363743
# Data columns (total 2 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   listing_id  1363744 non-null  int64
#  1   date        1363744 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 20.8+ MB

# %%
listings.loc[listings['number_of_reviews'] == 0]
# Out:
#              id                                               name    host_id  \
# 5          9359    Cozy, Central Paris: WALK or VELIB EVERYWHERE !      28422
# 50        33004                     flat to rent during the summer     143020
# 82        45175                Appartement XIX century near Buttes     199617
# 173      140211                STUDIO APT CITY CENTRE FOR NEW YEAR     683098
# 240      191531                    LOVELY DUPLEX  IN  LE  MARAIS       926484
# ...         ...                                                ...        ...
# 66895  43395769                              Studio champs Élysées  330233970
# 66896  43396154        F2 . Living room ´bedroom ´kitchen washroom  238702044
# 66897  43396700  La vue et l'espace, studio lumineux sous les t...  245787363
# 66898  43396938            Cute little flat in the center of Paris   34462615
# 66899  43397586      Room in flatshare to rent urgently short-term   20511323
#
#         host_name  neighbourhood_group    neighbourhood  latitude  longitude  \
# 5      Bernadette                  NaN           Louvre  48.85899    2.34735
# 50          Ketty                  NaN         Entrepôt  48.87842    2.35029
# 82         Simone                  NaN  Buttes-Chaumont  48.87564    2.38717
# 173        Freddy                  NaN           Bourse  48.86602    2.35117
# 240          Alex                  NaN           Temple  48.86322    2.36255
# ...           ...                  ...              ...       ...        ...
# 66895  Marc/Aicha                  NaN            Passy  48.86720    2.29865
# 66896      Akhtar                  NaN         Entrepôt  48.87023    2.36977
# 66897       Felix                  NaN         Entrepôt  48.88340    2.36098
# 66898    Catalina                  NaN          Reuilly  48.85072    2.37303
# 66899        Anna                  NaN           Temple  48.86600    2.36302
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 5      Entire home/apt     75             180                  0         NaN
# 50     Entire home/apt    114              30                  0         NaN
# 82        Private room     63               3                  0         NaN
# 173       Private room     50               1                  0         NaN
# 240    Entire home/apt    150               1                  0         NaN
# ...                ...    ...             ...                ...         ...
# 66895  Entire home/apt     60               2                  0         NaN
# 66896     Private room     40               1                  0         NaN
# 66897  Entire home/apt     32              30                  0         NaN
# 66898  Entire home/apt     65               2                  0         NaN
# 66899     Private room     30              30                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 5                    NaN                               1                72
# 50                   NaN                               1                 1
# 82                   NaN                               1                 0
# 173                  NaN                               1                 0
# 240                  NaN                               1                 0
# ...                  ...                             ...               ...
# 66895                NaN                               5                90
# 66896                NaN                               2                92
# 66897                NaN                               1               265
# 66898                NaN                               1               364
# 66899                NaN                               1                90
#
# [13999 rows x 16 columns]

# %%
reviews[['review_year', 'review_month', "review_day"]]= reviews['date'].str.split('-', expand = True)

# %%
reviews.head()
# Out:
#    listing_id        date review_year review_month review_day
# 0        2577  2019-01-02        2019           01         02
# 1        3109  2016-12-27        2016           12         27
# 2        3109  2016-12-28        2016           12         28
# 3        3109  2017-10-28        2017           10         28
# 4        3109  2017-11-03        2017           11         03

# %%
reviews.loc[reviews.review_year == '2019']
# Out:
#          listing_id        date review_year review_month review_day
# 0              2577  2019-01-02        2019           01         02
# 9              3109  2019-10-24        2019           10         24
# 161            5396  2019-01-02        2019           01         02
# 162            5396  2019-01-04        2019           01         04
# 163            5396  2019-01-10        2019           01         10
# ...             ...         ...         ...          ...        ...
# 1358161    41060159  2019-12-27        2019           12         27
# 1358275    41081987  2019-12-29        2019           12         29
# 1358327    41092919  2019-12-29        2019           12         29
# 1358330    41093879  2019-12-29        2019           12         29
# 1358429    41109856  2019-12-30        2019           12         30
#
# [446174 rows x 5 columns]

# %%
listings_ext = pd.read_csv("~/Desktop/TTP_DATA/JaquelinErazo-Capstone2/DATA/listings_extended.csv")

# %%
pd.set_option('display.max_columns', 110)

# %%
listings_ext.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2577  https://www.airbnb.com/rooms/2577  20200611183008   2020-06-15
# 1  3109  https://www.airbnb.com/rooms/3109  20200611183008   2020-06-16
# 2  4890  https://www.airbnb.com/rooms/4890  20200611183008   2020-06-14
# 3  5396  https://www.airbnb.com/rooms/5396  20200611183008   2020-06-14
# 4  7397  https://www.airbnb.com/rooms/7397  20200611183008   2020-06-15
#
#                                   name  \
# 0     Loft for 4 by Canal Saint Martin
# 1                         zen and calm
# 2  Quiet Historic & Cute  +Free Cruise
# 3       Explore the heart of old Paris
# 4     MARAIS - 2ROOMS APT - 2/4 PEOPLE
#
#                                              summary  \
# 0  100 m2 loft (1100 sq feet) with high ceiling, ...
# 1  Appartement très calme de 50M2 Utilisation de ...
# 2  Stylish & Classic One bedroom apartment for up...
# 3  Cozy, well-appointed and graciously designed s...
# 4          VERY CONVENIENT, WITH THE BEST LOCATION !
#
#                                                space  \
# 0  The district has any service or shop you may d...
# 1                   I bedroom appartment in Paris 14
# 2  2 Free River Cruise Tix with your booking !  M...
# 3  Small, well appointed studio apartment at the ...
# 4  PLEASE ASK ME BEFORE TO MAKE A REQUEST !!! No ...
#
#                                          description experiences_offered  \
# 0  100 m2 loft (1100 sq feet) with high ceiling, ...                none
# 1  I bedroom appartment in Paris 14 Good restaura...                none
# 2  Stylish & Classic One bedroom apartment for up...                none
# 3  Cozy, well-appointed and graciously designed s...                none
# 4  VERY CONVENIENT, WITH THE BEST LOCATION ! PLEA...                none
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  Good restaurants very close the Montparnasse S...
# 2  Called "Paris Next Great Neighborhood" from Tr...
# 3  You are within walking distance to the Louvre,...
# 4                                                NaN
#
#                                                notes  \
# 0                                                NaN
# 1                                                NaN
# 2  Apartment is on 1st Floor, one flight of stair...
# 3  The staircase leading up to the apartment is n...
# 4  Important: Be conscious that an apartment in a...
#
#                                              transit  \
# 0                      Metro lines : 4, 8, 3, 11, 9.
# 1  RER B Metro Ligne 13 Pernety Metro Ligne 13 Pl...
# 2  METRO: Arts et Metiers (Lines 3,11), Rambuteau...
# 3  The flat is close to two or three major metro ...
# 4  Metro station HÖTEL-DE-VILLE is 100 meters close.
#
#                                               access  \
# 0                                                NaN
# 1  A la demande, vous pouvez avoir accès à la cha...
# 2      Unlike most agencies, Cobblestone Paris is...
# 3  The flat includes its own modern bathroom, a w...
# 4                                                NaN
#
#                                          interaction  \
# 0                                                NaN
# 1                             yes I can help you out
# 2  An English-Speaking Greeter will Meet you at t...
# 3  We expect guests to operate rather independent...
# 4                                                NaN
#
#                                          house_rules  thumbnail_url  \
# 0                                                NaN            NaN
# 1                                                NaN            NaN
# 2                                 No Smoking No Pets            NaN
# 3  This is a small flat in a very old building th...            NaN
# 4  ELECTRICITY INCLUDED FOR NORMAL USING. PLEASE ...            NaN
#
#    medium_url                                        picture_url  \
# 0         NaN  https://a0.muscache.com/im/pictures/09da057c-0...
# 1         NaN  https://a0.muscache.com/im/pictures/baeae9e2-c...
# 2         NaN  https://a0.muscache.com/im/pictures/b144894f-b...
# 3         NaN  https://a0.muscache.com/im/pictures/52413/f9bf...
# 4         NaN  https://a0.muscache.com/im/pictures/67928287/3...
#
#    xl_picture_url  host_id                                host_url  \
# 0             NaN     2827  https://www.airbnb.com/users/show/2827
# 1             NaN     3631  https://www.airbnb.com/users/show/3631
# 2             NaN     6792  https://www.airbnb.com/users/show/6792
# 3             NaN     7903  https://www.airbnb.com/users/show/7903
# 4             NaN     2626  https://www.airbnb.com/users/show/2626
#
#                  host_name  host_since                          host_location  \
# 0                   Karine  2008-09-09  Casablanca, Grand Casablanca, Morocco
# 1                     Anne  2008-10-14           Paris, Île-de-France, France
# 2  Jennifer Of Cobblestone  2009-01-16           Paris, Île-de-France, France
# 3                   Borzou  2009-02-14             Istanbul, İstanbul, Turkey
# 4                   Franck  2008-08-30           Paris, Île-de-France, France
#
#                                           host_about host_response_time  \
# 0  Arrivée à Casablanca il y a 4 ans, je suis amo...       within a day
# 1                                                NaN                NaN
# 2  I am the owner of Cobblestone Paris Rentals\r\...       within a day
# 3  We are both journalists based in the Middle Ea...       within a day
# 4  I am a writer,51, author of novels, books of l...     within an hour
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0                88%                 100%                 f
# 1                NaN                  50%                 f
# 2               100%                 100%                 f
# 3               100%                 100%                 f
# 4               100%                  89%                 t
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/user/17fe6...
# 1  https://a0.muscache.com/im/users/3631/profile_...
# 2  https://a0.muscache.com/im/users/6792/profile_...
# 3  https://a0.muscache.com/im/users/7903/profile_...
# 4  https://a0.muscache.com/im/pictures/user/58f00...
#
#                                     host_picture_url  \
# 0  https://a0.muscache.com/im/pictures/user/17fe6...
# 1  https://a0.muscache.com/im/users/3631/profile_...
# 2  https://a0.muscache.com/im/users/6792/profile_...
# 3  https://a0.muscache.com/im/users/7903/profile_...
# 4  https://a0.muscache.com/im/pictures/user/58f00...
#
#              host_neighbourhood  host_listings_count  \
# 0                    République                  2.0
# 1                        Alésia                  1.0
# 2                     Le Marais                  5.0
# 3  Saint-Paul - Ile Saint-Louis                  1.0
# 4                     Le Marais                  3.0
#
#    host_total_listings_count  \
# 0                        2.0
# 1                        1.0
# 2                        5.0
# 3                        1.0
# 4                        3.0
#
#                                   host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 1          ['email', 'phone', 'facebook', 'reviews']                    t
# 2  ['email', 'phone', 'reviews', 'jumio', 'selfie...                    t
# 3  ['email', 'phone', 'facebook', 'google', 'revi...                    t
# 4  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
#
#   host_identity_verified                        street       neighbourhood  \
# 0                      t  Paris, Île-de-France, France          République
# 1                      f  Paris, Île-de-France, France              Alésia
# 2                      f  Paris, Ile-de-France, France  III Arrondissement
# 3                      t  Paris, Ile-de-France, France   IV Arrondissement
# 4                      t  Paris, Île-de-France, France   IV Arrondissement
#
#   neighbourhood_cleansed  neighbourhood_group_cleansed   city          state  \
# 0               Entrepôt                           NaN  Paris  Île-de-France
# 1           Observatoire                           NaN  Paris  Île-de-France
# 2                 Temple                           NaN  Paris  Ile-de-France
# 3         Hôtel-de-Ville                           NaN  Paris  Ile-de-France
# 4         Hôtel-de-Ville                           NaN  Paris  Île-de-France
#
#   zipcode market smart_location country_code country  latitude  longitude  \
# 0   75010  Paris  Paris, France           FR  France  48.86993    2.36251
# 1   75014  Paris  Paris, France           FR  France  48.83349    2.31852
# 2   75003  Paris  Paris, France           FR  France  48.86409    2.35651
# 3   75004  Paris  Paris, France           FR  France  48.85100    2.35869
# 4   75004  Paris  Paris, France           FR  France  48.85758    2.35275
#
#   is_location_exact property_type        room_type  accommodates  bathrooms  \
# 0                 t          Loft  Entire home/apt             4        2.0
# 1                 f     Apartment  Entire home/apt             2        1.0
# 2                 t     Apartment  Entire home/apt             4        1.0
# 3                 t     Apartment  Entire home/apt             2        1.0
# 4                 t     Apartment  Entire home/apt             4        1.0
#
#    bedrooms  beds       bed_type  \
# 0       2.0   2.0       Real Bed
# 1       0.0   1.0       Real Bed
# 2       1.0   2.0       Real Bed
# 3       0.0   1.0  Pull-out Sofa
# 4       2.0   2.0       Real Bed
#
#                                            amenities  square_feet    price  \
# 0  {TV,Internet,Wifi,Kitchen,Heating,Washer,Dryer...          NaN  $125.00
# 1  {Internet,Wifi,Kitchen,"Paid parking off premi...          NaN   $60.00
# 2  {TV,"Cable TV",Internet,Wifi,Kitchen,Heating,"...        344.0  $100.00
# 3  {Internet,Kitchen,Heating,Washer,"Smoke alarm"...          NaN  $115.00
# 4  {TV,"Cable TV",Internet,Wifi,Kitchen,"Paid par...          NaN  $119.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0          NaN           NaN            $0.00       $40.00                1
# 1      $490.00           NaN          $150.00       $60.00                1
# 2          NaN           NaN          $300.00       $50.00                2
# 3      $600.00     $2,000.00            $0.00       $36.00                1
# 4          NaN     $2,200.00          $200.00       $50.00                2
#
#   extra_people  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0        $0.00               3            1125                       3
# 1        $0.00               2              30                       2
# 2       $10.00               4             120                       4
# 3        $0.00               1            1125                       1
# 4       $10.00              10             130                       6
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       3                    1125                    1125
# 1                       2                      30                      30
# 2                       4                     120                     120
# 3                       1                    1125                    1125
# 4                      10                     130                     130
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# 0                     3.0                  1125.0    19 months ago
# 1                     2.0                    30.0     4 months ago
# 2                     4.0                   120.0     9 months ago
# 3                     1.0                  1125.0     2 months ago
# 4                     9.9                   130.0      6 weeks ago
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t               30               60               90
# 1                t               30               60               90
# 2                t               11               24               54
# 3                t               30               60               90
# 4                t                5               29               59
#
#    availability_365 calendar_last_scraped  number_of_reviews  \
# 0               365            2020-06-15                  1
# 1               365            2020-06-16                  9
# 2                55            2020-06-14                 22
# 3                90            2020-06-14                221
# 4               288            2020-06-15                268
#
#    number_of_reviews_ltm first_review last_review  review_scores_rating  \
# 0                      0   2019-01-02  2019-01-02                 100.0
# 1                      1   2016-12-27  2019-10-24                 100.0
# 2                      0   2011-11-22  2017-04-30                  96.0
# 3                     46   2009-06-30  2020-05-26                  90.0
# 4                     22   2011-04-08  2020-02-26                  94.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    10.0                       10.0                   10.0
# 1                    10.0                       10.0                   10.0
# 2                    10.0                       10.0                   10.0
# 3                     9.0                        9.0                    9.0
# 4                    10.0                        9.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                 10.0
# 1                         10.0                    10.0                 10.0
# 2                         10.0                    10.0                 10.0
# 3                         10.0                    10.0                  8.0
# 4                         10.0                    10.0                 10.0
#
#   requires_license        license  \
# 0                t            NaN
# 1                t            NaN
# 2                t            NaN
# 3                t  7510402838018
# 4                t  7510400829623
#
#                                   jurisdiction_names instant_bookable  \
# 0  {"translation missing: en.occupancy.taxes.juri...                t
# 1  {"translation missing: en.occupancy.taxes.juri...                f
# 2  {"translation missing: en.occupancy.taxes.juri...                t
# 3  {"translation missing: en.occupancy.taxes.juri...                f
# 4  {"translation missing: en.occupancy.taxes.juri...                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f                     flexible
# 2                        f                     moderate
# 3                        f  strict_14_with_grace_period
# 4                        f                     moderate
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               1
# 2                               1
# 3                               1
# 4                               2
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            1
# 2                                            1
# 3                                            1
# 4                                            2
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.06
# 1                                            0               0.21
# 2                                            0               0.21
# 3                                            0               1.66
# 4                                            0               2.39
